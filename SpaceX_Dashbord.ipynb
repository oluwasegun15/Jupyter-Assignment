# %%
import pandas as pd
import dash
import dash_html_components as html
import dash_core_components as dcc
from dash.dependencies import Input, Output
import plotly.express as px
# Out:
# C:\Users\WESTGA~1\AppData\Local\Temp/ipykernel_12284/1855361594.py:3: UserWarning:
# The dash_html_components package is deprecated. Please replace
# `import dash_html_components as html` with `from dash import html`
#   import dash_html_components as html
# C:\Users\WESTGA~1\AppData\Local\Temp/ipykernel_12284/1855361594.py:4: UserWarning:
# The dash_core_components package is deprecated. Please replace
# `import dash_core_components as dcc` with `from dash import dcc`
#   import dash_core_components as dcc

# %%
spacex_df = pd.read_csv("spacex_launch_dash.csv")

# %%
spacex_df.head()
# Out:
#    Unnamed: 0  Flight Number  Launch Site  class  Payload Mass (kg)  \
# 0           0              1  CCAFS LC-40      0                0.0
# 1           1              2  CCAFS LC-40      0                0.0
# 2           2              3  CCAFS LC-40      0              525.0
# 3           3              4  CCAFS LC-40      0              500.0
# 4           4              5  CCAFS LC-40      0              677.0
#
#   Booster Version Booster Version Category
# 0  F9 v1.0  B0003                     v1.0
# 1  F9 v1.0  B0004                     v1.0
# 2  F9 v1.0  B0005                     v1.0
# 3  F9 v1.0  B0006                     v1.0
# 4  F9 v1.0  B0007                     v1.0

# %%
max_payload = spacex_df['Payload Mass (kg)'].max()
min_payload = spacex_df['Payload Mass (kg)'].min()

# %%
app = dash.Dash(__name__)
server = app.server

uniquelaunchsites = spacex_df['Launch Site'].unique().tolist()
lsites = []
lsites.append({'label': 'All Sites', 'value': 'All Sites'})
for site in uniquelaunchsites:
 lsites.append({'label': site, 'value': site})



app.layout = html.Div(children=[html.H1('SpaceX Launch Records Dashboard',
                                        style={'textAlign': 'center', 'color': '#503D36',
                                               'font-size': 40}),




                                dcc.Dropdown(id='site_dropdown',options=lsites,placeholder='Select a Launch Site here', searchable = True , value = 'All Sites'),
                                html.Br(),


                                html.Div(dcc.Graph(id='success-pie-chart')),
                                html.Br(),

                                html.P("Payload range (Kg):"),

                                dcc.RangeSlider(
                                    id='payload_slider',
                                    min=0,
                                    max=10000,
                                    step=1000,
                                    marks = {
                                            0: '0 kg',
                                            1000: '1000 kg',
                                            2000: '2000 kg',
                                            3000: '3000 kg',
                                            4000: '4000 kg',
                                            5000: '5000 kg',
                                            6000: '6000 kg',
                                            7000: '7000 kg',
                                            8000: '8000 kg',
                                            9000: '9000 kg',
                                            10000: '10000 kg'
                                    },

                                    value=[min_payload,max_payload]
                                ),

                                html.Div(dcc.Graph(id='success-payload-scatter-chart')),

                                ])

@app.callback(
     Output(component_id='success-pie-chart',component_property='figure'),
     [Input(component_id='site_dropdown',component_property='value')]
)
def update_graph(site_dropdown):
    if (site_dropdown == 'All Sites'):
        df  = spacex_df[spacex_df['class'] == 1]
        fig = px.pie(df, names = 'Launch Site',hole=.3,title = 'Total Success Launches By all sites')
    else:
        df  = spacex_df.loc[spacex_df['Launch Site'] == site_dropdown]
        fig = px.pie(df, names = 'class',hole=.3,title = 'Total Success Launches for site '+site_dropdown)
    return fig

@app.callback(
     Output(component_id='success-payload-scatter-chart',component_property='figure'),
     [Input(component_id='site_dropdown',component_property='value'),Input(component_id="payload_slider", component_property="value")]
)
def update_scattergraph(site_dropdown,payload_slider):
    if site_dropdown == 'All Sites':
        low, high = payload_slider
        df  = spacex_df
        mask = (df['Payload Mass (kg)'] > low) & (df['Payload Mass (kg)'] < high)
        fig = px.scatter(
            df[mask], x="Payload Mass (kg)", y="class",
            color="Booster Version",
            size='Payload Mass (kg)',
            hover_data=['Payload Mass (kg)'])
    else:
        low, high = payload_slider
        df  = spacex_df.loc[spacex_df['Launch Site'] == site_dropdown]
        mask = (df['Payload Mass (kg)'] > low) & (df['Payload Mass (kg)'] < high)
        fig = px.scatter(
            df[mask], x="Payload Mass (kg)", y="class",
            color="Booster Version",
            size='Payload Mass (kg)',
            hover_data=['Payload Mass (kg)'])
    return fig



if __name__ == '__main__':
    app.run_server(debug=False)
# Out:
# Dash is running on http://127.0.0.1:8050/
#
#  * Serving Flask app '__main__'
#  * Debug mode: off
# WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on http://127.0.0.1:8050
# Press CTRL+C to quit
# 127.0.0.1 - - [28/Mar/2023 19:56:55] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [28/Mar/2023 19:56:55] "GET /_dash-component-suites/dash/deps/react-dom@16.v2_9_1m1680029588.14.0.min.js HTTP/1.1" 200 -
# 127.0.0.1 - - [28/Mar/2023 19:56:55] "GET /_dash-component-suites/dash/deps/polyfill@7.v2_9_1m1680029588.12.1.min.js HTTP/1.1" 200 -
# 127.0.0.1 - - [28/Mar/2023 19:56:55] "GET /_dash-component-suites/dash/deps/prop-types@15.v2_9_1m1680029588.8.1.min.js HTTP/1.1" 200 -
# 127.0.0.1 - - [28/Mar/2023 19:56:55] "GET /_dash-component-suites/dash/deps/react@16.v2_9_1m1680029588.14.0.min.js HTTP/1.1" 200 -
# 127.0.0.1 - - [28/Mar/2023 19:56:55] "GET /_dash-component-suites/dash/dcc/dash_core_components-shared.v2_9_0m1680029587.js HTTP/1.1" 200 -
# 127.0.0.1 - - [28/Mar/2023 19:56:56] "GET /_dash-component-suites/dash/html/dash_html_components.v2_0_9m1680029592.min.js HTTP/1.1" 200 -
# 127.0.0.1 - - [28/Mar/2023 19:56:56] "GET /_dash-component-suites/dash/dash_table/bundle.v5_2_3m1680029586.js HTTP/1.1" 200 -
# 127.0.0.1 - - [28/Mar/2023 19:56:56] "GET /_dash-component-suites/dash/dash-renderer/build/dash_renderer.v2_9_1m1680029586.min.js HTTP/1.1" 200 -
# 127.0.0.1 - - [28/Mar/2023 19:56:57] "GET /_dash-component-suites/dash/dcc/dash_core_components.v2_9_0m1680029587.js HTTP/1.1" 200 -
# 127.0.0.1 - - [28/Mar/2023 19:56:57] "GET /_dash-layout HTTP/1.1" 200 -
# 127.0.0.1 - - [28/Mar/2023 19:56:57] "GET /_dash-dependencies HTTP/1.1" 200 -
# 127.0.0.1 - - [28/Mar/2023 19:56:58] "GET /_dash-component-suites/dash/dcc/async-graph.js HTTP/1.1" 200 -
# 127.0.0.1 - - [28/Mar/2023 19:56:58] "GET /_dash-component-suites/dash/dcc/async-slider.js HTTP/1.1" 200 -
# 127.0.0.1 - - [28/Mar/2023 19:56:58] "GET /_dash-component-suites/dash/dcc/async-dropdown.js HTTP/1.1" 200 -
# 127.0.0.1 - - [28/Mar/2023 19:56:58] "GET /_dash-component-suites/dash/dcc/async-plotlyjs.js HTTP/1.1" 200 -
# 127.0.0.1 - - [28/Mar/2023 19:56:58] "GET /_favicon.ico?v=2.9.1 HTTP/1.1" 200 -
# 127.0.0.1 - - [28/Mar/2023 19:57:40] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [28/Mar/2023 19:57:40] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [28/Mar/2023 20:01:06] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [28/Mar/2023 20:01:06] "GET /_dash-component-suites/dash/deps/polyfill@7.v2_9_1m1680029588.12.1.min.js HTTP/1.1" 200 -
# 127.0.0.1 - - [28/Mar/2023 20:01:06] "GET /_dash-component-suites/dash/deps/react-dom@16.v2_9_1m1680029588.14.0.min.js HTTP/1.1" 200 -
# 127.0.0.1 - - [28/Mar/2023 20:01:06] "GET /_dash-component-suites/dash/deps/react@16.v2_9_1m1680029588.14.0.min.js HTTP/1.1" 200 -
# 127.0.0.1 - - [28/Mar/2023 20:01:06] "GET /_dash-component-suites/dash/deps/prop-types@15.v2_9_1m1680029588.8.1.min.js HTTP/1.1" 200 -
# 127.0.0.1 - - [28/Mar/2023 20:01:06] "GET /_dash-component-suites/dash/dash-renderer/build/dash_renderer.v2_9_1m1680029586.min.js HTTP/1.1" 200 -
# 127.0.0.1 - - [28/Mar/2023 20:01:06] "GET /_dash-component-suites/dash/dcc/dash_core_components.v2_9_0m1680029587.js HTTP/1.1" 200 -
# 127.0.0.1 - - [28/Mar/2023 20:01:06] "GET /_dash-component-suites/dash/dcc/dash_core_components-shared.v2_9_0m1680029587.js HTTP/1.1" 200 -
# 127.0.0.1 - - [28/Mar/2023 20:01:06] "GET /_dash-component-suites/dash/html/dash_html_components.v2_0_9m1680029592.min.js HTTP/1.1" 200 -
# 127.0.0.1 - - [28/Mar/2023 20:01:06] "GET /_dash-component-suites/dash/dash_table/bundle.v5_2_3m1680029586.js HTTP/1.1" 200 -
# 127.0.0.1 - - [28/Mar/2023 20:01:07] "GET /_dash-layout HTTP/1.1" 200 -
# 127.0.0.1 - - [28/Mar/2023 20:01:07] "GET /_dash-dependencies HTTP/1.1" 200 -
# 127.0.0.1 - - [28/Mar/2023 20:01:07] "GET /_favicon.ico?v=2.9.1 HTTP/1.1" 200 -
# 127.0.0.1 - - [28/Mar/2023 20:01:07] "GET /_dash-component-suites/dash/dcc/async-dropdown.js HTTP/1.1" 200 -
# 127.0.0.1 - - [28/Mar/2023 20:01:07] "GET /_dash-component-suites/dash/dcc/async-graph.js HTTP/1.1" 200 -
# 127.0.0.1 - - [28/Mar/2023 20:01:07] "GET /_dash-component-suites/dash/dcc/async-plotlyjs.js HTTP/1.1" 200 -
# 127.0.0.1 - - [28/Mar/2023 20:01:07] "GET /_dash-component-suites/dash/dcc/async-slider.js HTTP/1.1" 200 -
# 127.0.0.1 - - [28/Mar/2023 20:01:07] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [28/Mar/2023 20:01:07] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [28/Mar/2023 20:02:05] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [28/Mar/2023 20:02:11] "GET /_dash-component-suites/dash/deps/polyfill@7.v2_9_1m1680029588.12.1.min.js HTTP/1.1" 200 -
# 127.0.0.1 - - [28/Mar/2023 20:02:11] "GET /_dash-component-suites/dash/deps/react@16.v2_9_1m1680029588.14.0.min.js HTTP/1.1" 200 -
# 127.0.0.1 - - [28/Mar/2023 20:02:12] "GET /_dash-component-suites/dash/deps/react-dom@16.v2_9_1m1680029588.14.0.min.js HTTP/1.1" 200 -
# 127.0.0.1 - - [28/Mar/2023 20:02:12] "GET /_dash-component-suites/dash/deps/prop-types@15.v2_9_1m1680029588.8.1.min.js HTTP/1.1" 200 -
# 127.0.0.1 - - [28/Mar/2023 20:02:12] "GET /_dash-component-suites/dash/dash-renderer/build/dash_renderer.v2_9_1m1680029586.min.js HTTP/1.1" 200 -
# 127.0.0.1 - - [28/Mar/2023 20:02:12] "GET /_dash-component-suites/dash/dcc/dash_core_components-shared.v2_9_0m1680029587.js HTTP/1.1" 200 -
# 127.0.0.1 - - [28/Mar/2023 20:02:12] "GET /_dash-component-suites/dash/html/dash_html_components.v2_0_9m1680029592.min.js HTTP/1.1" 200 -
# 127.0.0.1 - - [28/Mar/2023 20:02:12] "GET /_dash-component-suites/dash/dcc/dash_core_components.v2_9_0m1680029587.js HTTP/1.1" 200 -
# 127.0.0.1 - - [28/Mar/2023 20:02:12] "GET /_dash-component-suites/dash/dash_table/bundle.v5_2_3m1680029586.js HTTP/1.1" 200 -
# 127.0.0.1 - - [28/Mar/2023 20:02:12] "GET /_favicon.ico?v=2.9.1 HTTP/1.1" 200 -
# 127.0.0.1 - - [28/Mar/2023 20:02:15] "GET /_dash-layout HTTP/1.1" 200 -
# 127.0.0.1 - - [28/Mar/2023 20:02:15] "GET /_dash-dependencies HTTP/1.1" 200 -
# 127.0.0.1 - - [28/Mar/2023 20:02:17] "GET /_dash-component-suites/dash/dcc/async-dropdown.js HTTP/1.1" 200 -
# 127.0.0.1 - - [28/Mar/2023 20:02:17] "GET /_dash-component-suites/dash/dcc/async-graph.js HTTP/1.1" 200 -
# 127.0.0.1 - - [28/Mar/2023 20:02:17] "GET /_dash-component-suites/dash/dcc/async-slider.js HTTP/1.1" 200 -
# 127.0.0.1 - - [28/Mar/2023 20:02:17] "GET /_dash-component-suites/dash/dcc/async-plotlyjs.js HTTP/1.1" 200 -
# 127.0.0.1 - - [28/Mar/2023 20:02:18] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [28/Mar/2023 20:02:18] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [28/Mar/2023 20:03:12] "POST /_dash-update-component HTTP/1.1" 200 -
# [2023-03-28 20:03:12,448] ERROR in app: Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "C:\Users\Westgate_Global\Desktop\sample_project_1\env\lib\site-packages\flask\app.py", line 2528, in wsgi_app
#     response = self.full_dispatch_request()
#   File "C:\Users\Westgate_Global\Desktop\sample_project_1\env\lib\site-packages\flask\app.py", line 1825, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "C:\Users\Westgate_Global\Desktop\sample_project_1\env\lib\site-packages\flask\app.py", line 1823, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "C:\Users\Westgate_Global\Desktop\sample_project_1\env\lib\site-packages\flask\app.py", line 1799, in dispatch_request
#     return self.ensure_sync(self.view_functions[rule.endpoint])(**view_args)
#   File "C:\Users\Westgate_Global\Desktop\sample_project_1\env\lib\site-packages\dash\dash.py", line 1283, in dispatch
#     ctx.run(
#   File "C:\Users\Westgate_Global\Desktop\sample_project_1\env\lib\site-packages\dash\_callback.py", line 447, in add_context
#     output_value = func(*func_args, **func_kwargs)  # %% callback invoked %%
#   File "C:\Users\WESTGA~1\AppData\Local\Temp/ipykernel_12284/4122516477.py", line 64, in update_graph
#     fig = px.pie(df, names = 'class',hole=.3,title = 'Total Success Launches for site '+site_dropdown)
# TypeError: can only concatenate str (not "NoneType") to str
# 127.0.0.1 - - [28/Mar/2023 20:03:12] "POST /_dash-update-component HTTP/1.1" 500 -
# 127.0.0.1 - - [28/Mar/2023 20:11:59] "GET /_dash-component-suites/dash/html/dash_html_components.min.js.map HTTP/1.1" 200 -
# 127.0.0.1 - - [28/Mar/2023 20:12:00] "GET /_dash-component-suites/dash/dcc/async-graph.js.map HTTP/1.1" 200 -
# 127.0.0.1 - - [28/Mar/2023 20:12:00] "GET /_dash-component-suites/dash/dcc/async-dropdown.js.map HTTP/1.1" 200 -
# 127.0.0.1 - - [28/Mar/2023 20:12:00] "GET /_dash-component-suites/dash/dcc/dash_core_components-shared.js.map HTTP/1.1" 200 -
# 127.0.0.1 - - [28/Mar/2023 20:12:00] "GET /_dash-component-suites/dash/dcc/dash_core_components.js.map HTTP/1.1" 200 -
# 127.0.0.1 - - [28/Mar/2023 20:12:00] "GET /_dash-component-suites/dash/dash_table/bundle.js.map HTTP/1.1" 200 -
# 127.0.0.1 - - [28/Mar/2023 20:23:53] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [28/Mar/2023 20:23:53] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [28/Mar/2023 20:25:13] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [28/Mar/2023 20:25:14] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [28/Mar/2023 20:26:34] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [28/Mar/2023 20:26:37] "POST /_dash-update-component HTTP/1.1" 200 -
